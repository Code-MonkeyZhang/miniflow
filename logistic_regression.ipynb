# %%
# %load_ext autoreload
# %autoreload 2
import copy
import math
import matplotlib.pyplot as plt
import numpy as np
import sys
from pathlib import Path

# 获取当前工作目录，假设 main.ipynb 位于项目根目录
current_dir = Path().resolve()
# 构建 src 目录的路径
src_dir = current_dir / 'src'
# 将 src 目录添加到 sys.path
if str(src_dir) not in sys.path:
    sys.path.append(str(src_dir))

from util import *
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 数据集
x_train = np.array([[0.5, 1.5], [1, 1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# 分离两个类别的数据
class_0 = x_train[y_train == 0]
class_1 = x_train[y_train == 1]

# 绘制散点图
plt.figure(figsize=(8, 6))
plt.scatter(class_0[:, 0], class_0[:, 1], color='red', label='Class 0')
plt.scatter(class_1[:, 0], class_1[:, 1], color='blue', label='Class 1')

# 设置图表标题和图例
plt.title('Classification Dataset Visualization')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()

# 显示图表
plt.show()

# %%
# Perform My logistic Regression
# x_train = np.array([[0.5, 1.5], [1, 1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
# y_train = np.array([0, 0, 0, 1, 1, 1])
# init parameters
num_iterations = 1000
learning_rate = 0.1
size = x_train.shape[0]
features = x_train.shape[1]
w_init = np.zeros(features)
b_init = 0.

w_out, b_out = regression(x_train, y_train, w_init, b_init,learning_rate,num_iterations,mode="logistic")
print(f"\nupdated parameters: w:{w_out}, b:{b_out}")



plot_decision_boundary(x_train, y_train, w_out, b_out)
plt.show()
# Out:
# Performing logistic regression
# Iteration    0: W [0.025      0.01666667],B0.0, Cost     0.21
# Iteration   10: W [0.17809031 0.10629544],B-0.05588925275840024, Cost     0.08
# Iteration   20: W [0.25691255 0.14116975],B-0.15200242178833664, Cost     0.06
# Iteration   30: W [0.31442092 0.16487499],B-0.2566158532900426, Cost     0.05
# Iteration   40: W [0.36395444 0.187565  ],B-0.3620119759939573, Cost     0.04
# Iteration   50: W [0.4093345  0.21144796],B-0.466243332472522, Cost     0.04
# Iteration   60: W [0.4518814  0.23676685],B-0.5688410562951495, Cost     0.03
# Iteration   70: W [0.49220121 0.26331148],B-0.6697217281544138, Cost     0.03
# Iteration   80: W [0.53066409 0.29080422],B-0.7689007071458162, Cost     0.03
# Iteration   90: W [0.56753986 0.3189925 ],B-0.8664165856838091, Cost     0.02
# Iteration  100: W [0.60304131 0.3476652 ],B-0.9623116161256773, Cost     0.02
# Iteration  110: W [0.6373414  0.37665038],B-1.056626980171843, Cost     0.02
# ...
